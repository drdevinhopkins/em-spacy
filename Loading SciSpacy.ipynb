# %%
import warnings
warnings.filterwarnings('ignore')

import spacy
import pandas as pd
from tqdm.notebook import trange, tqdm

from scispacy.abbreviation import AbbreviationDetector

nlp = spacy.load("en_core_sci_sm")

# Add the abbreviation pipe to the spacy pipeline.
nlp.add_pipe("abbreviation_detector")

# %%
from scispacy.linking import EntityLinker

nlp.add_pipe("scispacy_linker", config={"resolve_abbreviations": True, "linker_name": "umls"})

# %%
doc = nlp("Spinal and bulbar muscular atrophy (SBMA) is an \
           inherited motor neuron disease caused by the expansion \
           of a polyglutamine tract within the androgen receptor (AR). \
           SBMA can be caused by this easily.")

# Let's look at a random entity!
entity = doc.ents[1]

print("Name: ", entity)

# Each entity is linked to UMLS with a score
# (currently just char-3gram matching).
linker = nlp.get_pipe("scispacy_linker")
for umls_ent in entity._.kb_ents:
    print(linker.kb.cui_to_entity[umls_ent[0]])
# Out:
# Name:  bulbar
# CUI: C1947952, Name: anatomical bulb
# Definition: A rounded dilation or expansion in a canal, vessel, or organ.
# TUI(s): T017
# Aliases: (total: 2):
# 	 Bulbar, Bulb
# CUI: C0032372, Name: Poliomyelitis, Bulbar
# Definition: A form of paralytic poliomyelitis affecting neurons of the MEDULLA OBLONGATA of the brain stem. Clinical features include impaired respiration, HYPERTENSION, alterations of vasomotor control, and dysphagia. Weakness and atrophy of the limbs and trunk due to spinal cord involvement is usually associated. (From Adams et al., Principles of Neurology, 6th ed, p765)
# TUI(s): T047
# Aliases (abbreviated, total: 23):
# 	 Acute bulbar polioencephalitis, Bulbar Polio, Poliomyelitis, Medullary Involvement, BULBAR POLIO, Acute paralytic poliomyelitis specified as bulbar, Polio, Bulbar, Bulbar Poliomyelitis, Anterior acute poliomyelitis, Acute infantile paralysis, Acute paralytic poliomyelitis, bulbar
# CUI: C2586323, Name: Structure of fascial sheath of eyeball
# Definition: Sheath of the eyeball consisting of fascia extending from the OPTIC NERVE to the corneal limbus.
# TUI(s): T023
# Aliases (abbreviated, total: 20):
# 	 Eyeball, sheath, Vaginal bulbi, Capsule, Tenon, Bulbar sheath, Tenon's capsule, Fascia bulbi, Tenons Capsule, Structure of fascial sheath of eyeball, tenon capsule, Sheath of eyeball
# CUI: C1744560, Name: Bulbar urethra
# Definition: The portion of the penile urethra that spans the bulb of the penis.
# TUI(s): T023
# Aliases: (total: 5):
# 	 Structure of bulbar urethra, Bulbar urethra, Bulbar Portion of the Urethra, Structure of bulbar urethra (body structure), Bulbar Urethra
# CUI: C0030442, Name: Progressive bulbar palsy
# Definition: A motor neuron disease marked by progressive weakness of the muscles innervated by cranial nerves of the lower brain stem. Clinical manifestations include dysarthria, dysphagia, facial weakness, tongue weakness, and fasciculations of the tongue and facial muscles. The adult form of the disease is marked initially by bulbar weakness which progresses to involve motor neurons throughout the neuroaxis. Eventually this condition may become indistinguishable from AMYOTROPHIC LATERAL SCLEROSIS. Fazio-Londe syndrome is an inherited form of this illness which occurs in children and young adults. (Adams et al., Principles of Neurology, 6th ed, p1091; Brain 1992 Dec;115(Pt 6):1889-1900)
# TUI(s): T047
# [('C0002940', 1.0), ('C0751003', 0.8750523924827576), ('C0018789', 0.8587477207183838), ('C0162870', 0.8257237672805786), ('C0162872', 0.8218153119087219)]
# [('C0444706', 1.0), ('C0449770', 1.0), ('C2825498', 0.7975636124610901), ('C0336570', 0.773729681968689), ('C4725364', 0.7424883842468262)]
# [('C0007595', 0.8664658665657043), ('C4761515', 0.8664658665657043), ('C1654621', 0.8529700636863708), ('C0196940', 0.8281357884407043), ('C1516670', 0.8198980689048767)]
# [('C0814225', 1.0), ('C4684590', 0.8043907284736633), ('C3242014', 0.7881605625152588), ('C0021674', 0.7616507411003113), ('C0030854', 0.7527587413787842)]
# [('C0043240', 1.0), ('C0374711', 1.0), ('C1705181', 1.0), ('C4319951', 1.0), ('C1158765', 0.8171139359474182)]

# %%
entity = doc.ents[1]

print("Name: ", entity)

# Each entity is linked to UMLS with a score
# (currently just char-3gram matching).
linker = nlp.get_pipe("scispacy_linker")
for umls_ent in entity._.kb_ents:
    print(linker.kb.cui_to_entity[umls_ent[0]])
# Out:
# Name:  intubation
# CUI: C0021925, Name: Intubation
# Definition: Introduction of a tube into a hollow organ to restore or maintain patency if obstructed. It is differentiated from CATHETERIZATION in that the insertion of a catheter is usually performed for the introducing or withdrawing of fluids from the body.
# TUI(s): T061
# Aliases (abbreviated, total: 12):
# 	 Intubation, intubations, intubation procedures, Intubation, NOS, Intubation - action (qualifier value), intubation procedure, Intubations, Intubation Procedure, Intubation - action, Intubation (procedure)
# CUI: C0021932, Name: Intubation, Intratracheal
# Definition: A procedure involving placement of a tube into the trachea through the mouth or nose in order to provide a patient with oxygen and anesthesia.
# TUI(s): T061
# Aliases (abbreviated, total: 21):
# 	 Intubations, Intratracheal, Intratracheal Intubation, Insertion of endotracheal tube, Intubations, Endotracheal, Tracheal intubation, Intubation, Endotracheal, Insertion of endotracheal tube (procedure), Endotracheal Intubation, intubation tracheal, Intubation of trachea

# %%
entity._.kb_ents
# Out:
# [('C0021925', 1.0), ('C0021932', 0.78619384765625)]

# %%
cui_set = set()
for entity in doc.ents:
    try:
        for cui in entity._.kb_ents:
            cui_set.add(cui[0])
    except:
        continue
print(cui_set)
# Out:
# 34705', 'C1704435', 'C0155733', 'C4551669', 'C0005889', 'C0723712', 'C0796617', 'C0596164', 'C0001554', 'C4082936', 'C2985739', 'C2827486', 'C1559265', 'C3245481', 'C0023977', 'C4086674', 'C1171258', 'C3830526', 'C0023038', 'C1260873', 'C3274035', 'C1261322', 'C1518005', 'C1513770', 'C4687754', 'C1158765', 'C1704814', 'C0040053', 'C0024050', 'C0199230', 'C4319951', 'C1368999', 'C2735310', 'C1561559', 'C2936329', 'C0225851', 'C0700321', 'C3472245', 'C3899162', 'C0392148', 'C1704637', 'C4745009', 'C0037458', 'C1710459', 'C0019010', 'C0008307', 'C0751003', 'C0019345', 'C0021107', 'C1956346', 'C0021208', 'C0443318', 'C0282674', 'C5206952', 'C0040404', 'C4763881', 'C1883433', 'C0032790', 'C0151705', 'C0426747', 'C0042402', 'C1706180', 'C0034573', 'C0020649
C1427925', 'C0179650', 'C3251803', 'C0079595', 'C0455769', 'C4528226', 'C0030685', 'C1456616', 'C0086343', 'C0042397', 'C3714645', 'C1517945', 'C0184512', 'C0886296', 'C0308714', 'C0037428', 'C1858732', 'C0221464', 'C0600644', 'C1516670', 'C1272706', 'C1548384', 'C1706317', 'C3830346', 'C0016397', 'C1551356', 'C0233226', 'C1456803', 'C1549543', 'C4764141', 'C0243095', 'C0042401', 'C0282423', 'C0002346', 'C0042460', 'C0007220', 'C0079809', 'C0264714', 'C0026566', 'C4032686', 'C0518609', 'C0459649', 'C1524026', 'C1547427', 'C0221155', 'C0021440', 'C4528497', 'C0855322', 'C0178628', 'C020554 ...

# %%
for cui in sorted(cui_set):
    cui_to_ent = linker.kb.cui_to_entity[cui]
    if 'T184' in cui_to_ent[3]:
        print(cui_to_ent[1])
# Out:
# Abdomen, Acute
# Abdominal Pain
# Back Pain
# Eye Manifestations
# Fever
# Flank Pain
# Low Back Pain
# Pain
# Pain, Postoperative
# Rectal pain
# Signs and Symptoms
# Pain in testicle
# Chronic pain
# Acute onset pain
# Malaise
# Lower abdominal pain
# Fetal Extension
# back discomfort
# Absence of sensation
# Dull pain
# gastrointestinal gas
# Symptoms
# Mobility Limitation
# Discomfort
# Discharge, body substance
# Weakness
# Medically Unexplained Symptoms

# %%
a = linker.kb.cui_to_entity[cui][3]

# %%
if 'T023' in a:
    print('yes')
# Out:
# yes

# %%
old_cuis = pd.read_csv('listOfCuis.csv')
old_cuis
# Out:
#           cui
# 0    C0332158
# 1    C0449381
# 2    C0439606
# 3    C0005767
# 4    C0007595
# ..        ...
# 496  C0002766
# 497  C0056562
# 498  C0443131
# 499  C0589120
# 500  C0078988
#
# [501 rows x 1 columns]

# %%
new_cuis = pd.DataFrame(cui_set, columns=['cui'])
new_cuis
# Out:
#           cui
# 0    C0162578
# 1    C0425358
# 2    C0444706
# 3    C2316467
# 4    C0036679
# ..        ...
# 496  C0001122
# 497  C0020538
# 498  C0015801
# 499  C1514756
# 500  C0030608
#
# [501 rows x 1 columns]

# %%
new_df = old_cuis.append(new_cuis, ignore_index=False).drop_duplicates(keep='first')
new_df.to_csv('listOfCuis.csv', index=False)

# %%
for cui in cui_set:
    print(linker.kb.cui_to_entity[cui])
# Out:
# ot, fat, and muscle as emboli. It has been used in the treatment of spinal cord and INTRACRANIAL ARTERIOVENOUS MALFORMATIONS, renal arteriovenous fistulas, gastrointestinal bleeding, epistaxis, hypersplenism, certain highly vascular tumors, traumatic rupture of blood vessels, and control of operative hemorrhage.
# TUI(s): T061
# Aliases (abbreviated, total: 24):
# 	 Embolization Therapy, Embolization - action, Embolisation procedure, therapy, embolization, Embolotherapy, Therapeutic Embolizations, embolotherapy, Embolisation - action, Embolisation, embolization procedure
# CUI: C0032659, Name: geographic population
# Definition: The total number of individuals inhabiting a particular region or area.
# TUI(s): T081
# Aliases: (total: 5):
# 	 populations, Population (social concept), Population, population, Populations
# CUI: C0205396, Name: Identified
# Definition: The procedure of having an identity established.
# TUI(s): T080
# Aliases: (total: 6):
# 	 Identification, Identified, Discernible, identified, Identified (qualifier value), Identifiable
# CUI: C1710254, Name: Surgical Graft Device
# Definition: A tissue or organ surgically moved from a donor to a recipient or from site to site of an individual.
# TUI(s): T073
# Aliases: (total: 1):
# 	 Surgical Graft
# CUI: C0524461, Name: Structure of lumen of body system
# Definition: The cavity or channel within a tube or tubular organ such as a blood vessel or the intestine.
# TUI(s): T030
# Aliases: (total: 8):
# 	 Lumen, NOS, Lumen of body system, Lumen, Structure of lumen of body system (body structure), lumen, Structure of lumen of body system, Lumen of body system, NOS, lumens
# CUI: C0085393, Name: Immunocompromised Host
# Definition: A human or animal whose immunologic mechanism is deficient because of an immunodeficiency disorder or other disease or as the result of the administration of immunosuppressive drugs or radiation.
# TUI(s): T033
# Aliases (abbreviated, total: 28):
# 	 Host, Immunocompromised, Immunosuppressed Patient, immunocompromised patients, Patient immunosuppressed (finding), Patient immunosuppressed, Hosts, Immunocompromised, Immunosuppressed Host, immunocompromising, Immunocompromised Patient, immunosuppressed patient
# CUI: C0589507, Name: Cognitive function: initiation
# Definition: None
# TUI(s): T041
# Aliases: (total: 4):
# 	 Initiation, Cognitive function: initiation, Cognitive function: initiation (observable entity), initiation
# CUI: C0019994, Name: Hospitals
# Definition: Institutions with an organized medical staff which provide medical care to patients.
# TUI(s): T073, T093
# Aliases: (total: 7):
# 	 Hospitals, HOSPITAL, Hospital, NOS, hospital, hospitals, Hospital, hospital environment
# CUI: C1548384, Name: dictated - ParticipationMode
# Definition: <p>Participation by pre-recorded voice. Communication is limited to one direction (from the recorder to recipient).</p>
# TUI(s): T169
# Aliases: (total: 1):
# 	 dictated
# CUI: C0005767, Name: Blood
# Definition: The body fluid that circulates in the vascular system (BLOOD VESSELS). Whole blood includes PLASMA and BLOOD CELLS.
# TUI(s): T031
# Aliases: (total: 8):
# 	 Blood, Portion of blood, Haema, Blood, NOS, BLOOD, blood, Sanguis, Blood (substance)
# CUI: C0205191, Name: chronic
# Definition: A disease or condition that persists or progresses over a long period of time.
# TUI(s): T079
# Aliases: (total: 5):
# 	 Chronic, Chronic course - prolonged duration, CHRONIC, chronic, Chronic (qualifier value)
# CUI: C0205421, Name: Deferred
# Definition: Hold back to a later time.
# TUI(s): T079
# Aliases: (total: 7):
# 	 Defer, Deferred, deferred, delayed, Deferral, Delayed, Delay
# CUI: C0199168, Name: Medical service
# Definition: <p>Provision of diagnostic and/or therapeutic treatment.</p>
# TUI(s): T058
# Aliases: (total: 6):
# 	 Medical service, Medical, medical service, Medical service (procedure), service medical, MEDICAL PROCEDURES AND SERVICES
# CUI: C0185130, Name: Operation on musculoskeletal system
# Definition: None
# TUI(s): T061
# Aliases: (total: 8):
# 	 OPERATIONS ON THE MUSCULOSKELETAL SYSTEM, MUSCULOSKELETAL SYSTEM: GENERAL AND MISCELLANEOUS OPERATIVE PROCEDURES, Operations on the musculoskeletal system, Operation on musculoskeletal system, NOS, OPERATIVE PROCEDURES ON THE MUSCULOSKELETAL SYSTEM, Musculoskeletal procedure, Operation on musculoskeletal system (procedure), GENERAL OPERATIVE PROCEDURES ON THE MUSCULOSKELETAL SYSTEM
# CUI: C1709595, Name: Pooled Sample
# Definition: A mix of specimens from multiple individuals representing multiple sex groups.
# TUI(s): T167
# Aliases: (total: 5):
# 	 Pooled, Pooled Sample, Pooled specimen (specimen), Pooled Specimen, Pooled specimen
# CUI: C0026538, Name: Morbidity - disease rate
# Definition: The proportion of patients with a particular disease during a given year per given unit of population.
# TUI(s): T081
# Aliases: (total: 7):
# 	 morbidity, morbidities, Morbidity, Morbidities, disorder incidence, disease rates, disease rate
# CUI: C0442120, Name: Intraperitoneal
# Definition: Within the peritoneal cavity (the area that contains the abdominal organs).
# TUI(s): T082
# Aliases: (total: 5):
# 	 IP, intraperitoneal, Intraperitoneal, IP - Intraperitoneal, Intraperitoneal (qualifier value)
# CUI: C0587605, Name: Palliative care service
# Definition: <p>Provision of care for patients who are living or dying from an advanced illness.</p>
# TUI(s): T093
# Aliases: (total: 3):
# 	 Palliative, Palliative care service (qualifier value), Palliative care service
# CUI: C0020517, Name: Hypersensitivity
# Definition: Altered reactivity to an antigen, which can result in pathologic reactions upon subsequent exposure to that particular antigen.
# TUI(s): T046
# Aliases (abbreviated, total: 44):
# 	 Allergies, Hypersensitivity reaction (disorder), hypersensitivity, hypersensitivity symptom, hypersensitivities, allergies, Hypersensitive, Allergic Reaction, HYPERSENSITIVITY REACTION (NOS), Sensitivity
# CUI: C0042460, Name: Vena cava structure
# Definition: The inferior and superior venae cavae.
# TUI(s): T023
# Aliases (abbreviated, total: 14):
# 	 VENA CAVA, Cavae, Venae, Venae cavae, Vena caval, Venae Cavae, Vena Cava, Vena caval structure (body structure), Vena cava, NOS, vena caval, cava vena
# CUI: C0040053, Name: Thrombosis
# Definition: Formation and development of a thrombus or blood clot in the blood vessel.
# TUI(s): T046
# Aliases (abbreviated, total: 11):
# 	 THROMBOSIS, Thrombosis, Thromboses, Thrombosis, NOS, Thrombotic disorder (navigational concept), Thrombosis (qualifier value), Thrombosed, thrombosis, Thrombotic disorder, thrombotic disorder
# CUI: C0010294, Name: creatinine
# Definition: The breakdown product of creatine, a constituent of muscle tissue, that is excreted by the kidney and whose serum level is used to evaluate kidney function.
# TUI(s): T109, T123
# Aliases: (total: 7):
# 	 creatinines, creatinina, 4H-Imidazol-4-one, 2-amino-1,5-dihydro-1-methyl-, creatinine, Creatinine (substance), Creatinine, CREATININE
# CUI: C0007226, Name: Cardiovascular system
# Definition: The HEART and the BLOOD VESSELS by which BLOOD is pumped and circulated through the body.
# TUI(s): T022
# Aliases (abbreviated, total: 28):
# 	 Cardiovascular Organ System, Cardio-pericardial, Cardiovascular structure, Circulatory Systems, Circulatory system, NOS, CARDIOVASCULAR SYSTEM, CV system, Organ System, Cardiovascular, Structure of cardiovascular system (body structure), circulatory
# CUI: C0162864, Name: Tunica Intima
# Definition: The innermost layer of an artery or vein, made up of one layer of endothelial cells and supported by an internal elastic lamina.
# TUI(s): T023
# Aliases (abbreviated, total: 18):
# 	 Tunica intima of vessel, NOS, Tunica intima, NOS, Vascular Intima, Intimas, Vascular, intima, Structure of tunica intima of blood vessel (body structure), intimas, tunica intima, TUNICA INTIMA, Tunica intima
# CUI: C0332459, Name: Compressed structure
# Definition: None
# TUI(s): T169
# Aliases: (total: 10):
# 	 Tamponade, NOS, Compression (morphologic abnormality), Compression, NOS, tamponade, compressions, Compressed structure, compression, Compression, Compressed structure, NOS, compressed structure
# CUI: C0034866, Name: Recommendation
# Definition: Advice telling someone what the best thing to do is.
# TUI(s): T078
# Aliases: (total: 7):
# 	 Recommendation, Recommended, recommended, recommends, recommend, recommendations, recommendation
# CUI: C0443252, Name: Long-term
# Definition: Involving or being in effect for a long time.
# TUI(s): T079
# Aliases: (total: 6):
# 	 long-term, Long Term, long term, long terms, Long-Term, term long
# CUI: C0015259, Name: Exercise
# Definition: Physical activity which is usually regular and done with the intention of improving or maintaining PHYSICAL FITNESS or HEALTH. Contrast with PHYSICAL EXERTION which is concerned largely with the physiologic and metabolic response to energy expenditure.
# TUI(s): T056
# Aliases (abbreviated, total: 23):
# 	 Physical exercise, NOS, Exercises, Physical, Exercise (observable entity), Activity, Physical, Exercises, Physical Activities, Physical Exercise, Activities, Physical, PHYSICAL EXERCISES, Exercise, Physical
# CUI: C0871208, Name: Rating (action)
# Definition: The act of ascertaining or fixing the value or worth of something.
# TUI(s): T052
# Aliases: (total: 3):
# 	 Rated, Rate, Rating
# CUI: C0116569, Name: esmolol
# Definition: The hydrochloride salt form of esmolol, a short, rapid-acting, selective beta-adrenergic receptor blocker, devoid of intrinsic sympathomimetic activity, and with anti-arrhythmic, antihypertensive and potential analgesic activities. Upon intravenous administration, esmolol binds to and blocks the beta-1 receptor in the myocardium thereby preventing the action of epinephrine and norepinephrine. This leads to a reduction in the force and rate of cardiac contractions and thereby preventing tachycardia, arrythmias and/or hypertension. At higher doses, esmolol also blocks beta-2 receptors located in bronchial and vascular smooth muscle, thereby leading to smooth muscle relaxation. In addition, esmolol exerts a peripheral analgesic effect and intraoperative use of this agent may decrease the amount of opioid administration postoperatively. As the ester moiety in esmolol is rapidly hydrolyzed byplasma esterases, this agent has a very short half-life. Check for "https://www.cancer.gov/about-cancer/treatment/clinical-trials/intervention/C72617" active clinical trials using this agent. ("http://ncit.nci.nih.gov/ncitbrowser/ConceptReport.jsp?dictionary=NCI%20Thesaurus&code=C72617" NCI Thesaurus)
# TUI(s): T109, T121
# Aliases (abbreviated, total: 11):
# 	 3-[4-(2-Hydroxy-3-isopropylamino-propoxy)-phenyl]-propionic acid methyl ester, Esmolol (substance), methyl p-(2-hydroxy-3-(isopropylamino)propoxy)hydrocinnamate, (±)-methyl p-(2-hydroxy-3-(isopropylamino)propoxy)hydrocinnamate, ESMOLOL, Methyl 4-(2-hydroxy-3-((1-methylethyl)amino)propoxy)benzenepropanoate, esmolol, Esmolol-containing product, Esmolol, Product containing esmolol (medicinal product)
# CUI: C1555029, Name: reverses
# Definition: <p>A relationship between a source Act that seeks to reverse or undo the action of the prior target Act.</p><p>Example: A posted financial transaction (e.g., a debit transaction) was applied in error and must be reversed (e.g., by a credit transaction) the credit transaction is identified as an undo (or reversal) of the prior target transaction.</p><p>Constraints: the "completion track" mood of the target Act must be equally or more "actual" than the source act. I.e., when the target act is EVN the source act can be EVN, or any INT. If the target act is INT, the source act can be INT.</p>
# TUI(s): T169
# Aliases: (total: 0):
#
# CUI: C0037533, Name: sodium nitroprusside
# Definition: None
# TUI(s): T109, T121
# Aliases (abbreviated, total: 11):
# 	 Sodium Nitroprusside, Sodium nitroprusside (substance), nitroprusside sodium, Sodium nitroferricyanide, Sodium nitroprusside, Disodium Salt Nitroprusside, Nitroprusside, Sodium, Nitroprusside, Disodium Salt, sodium nitroprusside, Nitroprusside, sodium
# CUI: C3242381, Name: no longer in use
# Definition: <p><b>Description:</b>This name is no longer in use (note: Names may also carry valid time ranges . This code is used to cover the situations where it is known that the name is no longer valid, but no particular time range for its use is known)</p>
# TUI(s): T033
# Aliases: (total: 1):
# 	 no longer in use
# CUI: C0439801, Name: Limited (extensiveness)
# Definition: Restricted or in amount, size, or extent.
# TUI(s): T169
# Aliases: (total: 7):
# 	 limit, Limit, limiting, Limited (qualifier value), limited, limits, Limited
# CUI: C0032074, Name: Cognitive function: planning
# Definition: cognitive function
# TUI(s): T041
# Aliases: (total: 4):
# 	 planning, Cognitive function: planning, Cognitive function: planning (observable entity), Planning
# CUI: C0025424, Name: mercury
# Definition: A silver metallic element that exists as a liquid at room temperature. It has the atomic symbol Hg (from hydrargyrum, liquid silver), atomic number 80, and atomic weight 200.59. Mercury is used in many industrial applications and its salts have been employed therapeutically as purgatives, antisyphilitics, disinfectants, and astringents. It can be absorbed through the skin and mucous membranes which leads to MERCURY POISONING. Because of its toxicity, the clinical use of mercury and mercurials is diminishing.
# TUI(s): T131, T196
# Aliases (abbreviated, total: 14):
# 	 hg, metal mercury, Hg, MERCURY, Liquid Silver, mercury, Hydrargyrum, Hg - Mercury, Mercury, NOS, Quicksilver
# CUI: C1555577, Name: arrival - ActRelationshipType
# Definition: <p>The relationship that links to a Transportation Act (target) from another Act (source) indicating that the subject of the source Act entered into the source Act by means of the target Transportation act.</p>
# TUI(s): T169
# Aliases: (total: 2):
# 	 arrival, ActRelationshipArrival
# CUI: C0374711, Name: Surgical repair
# Definition: Restoring, to the extent possible, the natural anatomical structure
# TUI(s): T061
# Aliases (abbreviated, total: 13):
# 	 repair, repair surgical, Repair - action (qualifier value), Surgical repair, NOS, Repair, Surgical repair, Repair - action, Repair, NOS, repairing, surgical repair
# CUI: C0205360, Name: Stable status
# Definition: The quality of being free from change or variation or not taking part readily in chemical change.
# TUI(s): T080
# Aliases: (total: 9):
# 	 Stable status, stabilities, stability, stabling, Stability, Stable (qualifier value), Stable, STABLE, stable
# CUI: C0027361, Name: Persons
# Definition: Persons as individuals (e.g., ABORTION APPLICANTS) or as members of a group (e.g., HISPANIC AMERICANS). It is not used for members of the various professions (e.g., PHYSICIANS) or occupations (e.g., LIBRARIANS) for which OCCUPATIONAL GROUPS is available.
# TUI(s): T098
# Aliases: (total: 9):
# 	 person, People, Person (person), persons, Person, Individual, Persons, peoples, people
# CUI: C1880156, Name: Comprehensive
# Definition: Broad in scope; including all or everything.
# TUI(s): T080
# Aliases: (total: 0):
#
# CUI: C0232902, Name: migrated
# Definition: None
# TUI(s): T169
# Aliases: (total: 4):
# 	 Migrated, migrating, migrate, migrates
# CUI: C0150312, Name: Present
# Definition: Being or existing in a specified place or at the specified time.
# TUI(s): T033
# Aliases: (total: 9):
# 	 Presence of, present, Presence, In, Found, Present, of presence, PRESENT, Present (qualifier value)
# CUI: C0884358, Name: Performed
# Definition: Executed and carried through to completion.
# TUI(s): T169
# Aliases: (total: 5):
# 	 PERFORMED, Performed (qualifier value), performed, Performed, Perform
# CUI: C0005889, Name: Body Fluids
# Definition: Liquid components of living organisms.
# TUI(s): T031
# Aliases (abbreviated, total: 16):
# 	 Fluid, Body, Body fluid, NOS, Body Fluid, body fluids substance, Body fluid, Portion of body fluid, Body Fluids and Substances, FLUID, body fluids, Body Fluid or Substance
# CUI: C0030705, Name: Patients
# Definition: Individuals participating in the health care system for the purpose of receiving therapeutic, diagnostic, or preventive procedures.
# TUI(s): T101
# Aliases: (total: 8):
# 	 patient, Patients, PATIENT, LAY USER/PATIENT, Patient (person), patients, Patient, PT
# CUI: C0031809, Name: Physical Examination
# Definition: Systematic and thorough inspection of the patient for physical signs of disease or abnormality.
# TUI(s): T058
# Aliases (abbreviated, total: 45):
# 	 Physical Assessment, examination procedure, Physical examination procedure (procedure), assessment, Exams, Physical, PE - Physical examination, Physical, Assessment, Physical assessment, NOS, PHYSICAL EXAMINATION PROCEDURES
# CUI: C0009450, Name: Communicable Diseases
# Definition: An illness caused by an infectious agent or its toxins that occurs through the direct or indirect transmission of the infectious agent or its products from an infected individual or via an animal, vector or the inanimate environment to a susceptible animal or human host.
# TUI(s): T047
# Aliases (abbreviated, total: 43):
# 	 Clinical Infection, Diseases, Infectious, Disease, Infectious, infection, disease caused by microorganism, Communicable Disease, Infection, Infectious disease, Diseases, Communicable, infectious diseases
# CUI: C0021358, Name: Inferior Colliculus
# Definition: The posterior pair of the quadrigeminal bodies which contain centers for auditory function.
# TUI(s): T023
# Aliases (abbreviated, total: 30):
# 	 Posterior colliculus, Inferiors, Colliculus, Caudal Colliculus, Testes, Corpus quadrigeminum inferius, Colliculus Inferiors, Colliculus, Inferior, posterior colliculus, Posterior quadrigeminal body, Inferior Colliculi
# CUI: C0011331, Name: Dental Procedures
# Definition: The total of dental diagnostic, preventive, and restorative services provided to meet the needs of a patient (from Illustrated Dictionary of Dentistry, 1982).
# TUI(s): T061
# Aliases (abbreviated, total: 23):
# 	 Dental procedures, Dental care, NOS, dental procedure, Dental Procedure, Dental-oral procedure or service, care dental, dental care, dental procedures, Dental care (regime/therapy), Dental Care
# CUI: C0001779, Name: Age
# Definition: How long something has existed; elapsed time since birth.
# TUI(s): T032
# Aliases (abbreviated, total: 13):
# 	 Has age, Chronological Age, Age (qualifier value), Current chronological age (observable entity), AGE, Current chronological age, Postnatal age, Age, NOS, Age - descriptor, Aged
# CUI: C0001122, Name: Acidosis
# Definition: A pathologic condition of acid accumulation or depletion of base in the body. The two main types are RESPIRATORY ACIDOSIS and metabolic acidosis, due to metabolic acid build up.
# TUI(s): T046
# Aliases: (total: 8):
# 	 Acidoses, Acidosis NOS, ACIDOSIS, Acidosis, NOS, acidosis, Acidosis (disorder), Acidosis, acidoses
# CUI: C0020538, Name: Hypertensive disease
# Definition: Persistently high systemic arterial BLOOD PRESSURE. Based on multiple readings (BLOOD PRESSURE DETERMINATION), hypertension is currently defined as when SYSTOLIC PRESSURE is consistently greater than 140 mm Hg or when DIASTOLIC PRESSURE is consistently 90 mm Hg or more.
# TUI(s): T047
# Aliases (abbreviated, total: 57):
# 	 Hypertension, arterial, HYPERTENSION ARTERIAL, Elevated blood pressure, high bp, arterial hypertension systemic, hypertension, Hypertensive disease, NOS, HTN, hypertensive disorder, hyperpiesia
# CUI: C0015801, Name: Structure of femoral artery
# Definition: The main artery of the thigh, a continuation of the external iliac artery.
# TUI(s): T023
# Aliases (abbreviated, total: 16):
# 	 Structure of femoral artery (body structure), FEMORAL ARTERIES, Femoral artery, NOS, Femoral artery, Structure of femoral artery, ARTERY, FEMORAL, Arteria femoralis, Artery, Femoral, arteries femoral, Femoral Arteries
# CUI: C1514756, Name: Receive
# Definition: To take, accept, or get something offered.
# TUI(s): T080
# Aliases: (total: 4):
# 	 RECEIVED, Received, Receive, RECEIVING
# CUI: C0030608, Name: Particle Size
# Definition: Relating to the size of solids.
# TUI(s): T081
# Aliases: (total: 6):
# 	 particles size, Size, Particle, Particle Sizing, Particle Sizes, particle size, Sizes, Particle

# %%
f = open("topics/AAA.txt", "r")
output = f.read().replace('※','')
f.close()
doc = nlp(output)

# %%
cui_set = set()
for entity in doc.ents:
    try:
        cui_set.add(entity._.kb_ents[0][0])
    except:
        continue
print(cui_set)
# Out:
# {'C0162578', 'C0425358', 'C0444706', 'C2316467', 'C0036679', 'C0679688', 'C1554961', 'C0266835', 'C0034896', 'C0231220', 'C0205087', 'C0002921', 'C0184512', 'C0600210', 'C0205216', 'C0556984', 'C0003855', 'C0017181', 'C0029266', 'C0205283', 'C0205108', 'C0086805', 'C0031166', 'C0332197', 'C1279919', 'C0007820', 'C0003483', 'C4706466', 'C0020488', 'C0035273', 'C0934502', 'C0079809', 'C0456389', 'C0020283', 'C0220912', 'C3824793', 'C0547047', 'C0162871', 'C0018802', 'C0018943', 'C0444976', 'C0003860', 'C1517945', 'C0225317', 'C0003835', 'C0020792', 'C0302828', 'C0445204', 'C0220920', 'C0043251', 'C0443318', 'C0032854', 'C0032214', 'C0036492', 'C0020887', 'C0078988', 'C0332181', 'C0001811', 'C0332152', 'C0586909', 'C0549177', 'C5204628', 'C0003850', 'C0016199', 'C0019080', 'C0700321', 'C0239307', 'C0013227', 'C0728940', 'C4086268', 'C1504464', 'C0004793', 'C0037088', 'C0695347', 'C1762617', 'C0333205', 'C0175566', 'C0439658', 'C0003486', 'C0028754', 'C0005779', 'C1523987', 'C0003842', 'C0205351', 'C1880906', 'C0
'C0332147', 'C0524637', 'C0443294', 'C0086045', 'C0021149', 'C0855279', 'C0000737', 'C0004604', 'C0243032', 'C2698872', 'C0449255', 'C0028778', 'C3242296', 'C0041618', 'C0002915', 'C0003496', 'C0087111', 'C0030193', 'C0151705', 'C0035648', 'C0085134', 'C0029921', 'C0005910', 'C0242350', 'C0886296', 'C0000731', 'C0449416', 'C0 ...

# %%
old_cuis = pd.read_csv('listOfCuis.csv')
new_cuis = pd.DataFrame(cui_set, columns=['cui'])
new_df = old_cuis.append(new_cuis, ignore_index=False).drop_duplicates(keep='first')
new_df
# Out:
#           cui
# 0    C0332158
# 1    C0449381
# 2    C0439606
# 3    C0005767
# 4    C0007595
# ..        ...
# 496  C0002766
# 497  C0056562
# 498  C0443131
# 499  C0589120
# 500  C0078988
#
# [501 rows x 1 columns]

# %%
new_cuis
# Out:
#           cui
# 0    C0162578
# 1    C0425358
# 2    C0444706
# 3    C2316467
# 4    C0036679
# ..        ...
# 496  C0001122
# 497  C0020538
# 498  C0015801
# 499  C1514756
# 500  C0030608
#
# [501 rows x 1 columns]

# %%
df = pd.read_excel('corependium.xlsx')

# %%
df.head()

# %%
df = pd.read_csv('scraped2.csv')

# %%
df
# Out:
#                                                  content  \
# 0                                           Rapid Access
# 1                       Approach to the Critical Patient
# 2      When a ruptured AA is suspected, consider imme...
# 3      Intraperitoneal rupture will lead to intra-abd...
# 4      Retroperitoneal rupture may be difficult to id...
# ...                                                  ...
# 61964  An increased risk of infection has been used a...
# 61965  In general, accepted indications for prophylac...
# 61966  Antibiotics for prophylaxis are similar to tho...
# 61967  Although IV antibiotics achieve therapeutic ti...
# 61968  The use of topical antibiotic cream is support...
#
#                            topic
# 0      Abdominal Aortic Aneurysm
# 1      Abdominal Aortic Aneurysm
# 2      Abdominal Aortic Aneurysm
# 3      Abdominal Aortic Aneurysm
# 4      Abdominal Aortic Aneurysm
# ...                          ...
# 61964           Wound Management
# 61965           Wound Management
# 61966           Wound Management
# 61967           Wound Management
# 61968           Wound Management
#
# [61969 rows x 2 columns]

# %%
corependium_text = '\n'.join(df.content.astype(str))

# %%
symptom_cuis = []
for line in tqdm(df.content.astype(str).tolist()):
    doc = nlp(line)
    # print(doc.ents)
    for entity in doc.ents:
        try:
            # print(entity._.kb_ents)
            for cui in entity._.kb_ents:
                # print(cui)
                cui_to_ent = linker.kb.cui_to_entity[cui[0]]
                # print(cui_to_ent)
                if 'T184' in cui_to_ent[3]:
                    # print('success')
                    if cui[0] not in symptom_cuis:
                        symptom_cuis.append(cui[0])    
        except:
            continue
symptom_cuis
# Out:
#   0%|          | 0/61969 [00:00<?, ?it/s]
# ['C0000737',
#  'C0232495',
#  'C3839861',
#  'C1457887',
#  'C0150055',
#  'C0030193',
#  'C0184567',
#  'C0037088',
#  'C1565249',
#  'C2926602',
#  'C0015411',
#  'C0004604',
#  'C0024031',
#  'C0000727',
#  'C0278144',
#  'C0235706',
#  'C2364135',
#  'C0016199',
#  'C0039591',
#  'C0034886',
#  'C0278134',
#  'C0233226',
#  'C0015967',
#  'C0231218',
#  'C0596601',
#  'C3714552',
#  'C0030201',
#  'C0233763',
#  'C2985299',
#  'C2985336',
#  'C0037011',
#  'C0027498',
#  'C0013404',
#  'C0016204',
#  'C0002962',
#  'C0039070',
#  'C0008031',
#  'C0008035',
#  'C0030200',
#  'C0877303',
#  'C0476273',
#  'C0242706',
#  'C0745417',
#  'C0029166',
#  'C0037285',
#  'C3665346',
#  'C0221423',
#  'C0521989',
#  'C0232493',
#  'C0239377',
#  'C0027497',
#  'C0012833',
#  'C0220870',
#  'C0015672',
#  'C0700200',
#  'C0023380',
#  'C0596240',
#  'C0235710',
#  'C0085624',
#  'C0234230',
#  'C0241057',
#  'C0013395',
#  'C1456399',
#  'C0458259',
#  'C0232292',
#  'C0028643',
#  'C0278145',
#  'C0236000',
#  'C0232288',
#  'C0042963',
#  'C1321587',
#  'C0008033',
#  'C0027424',
#  'C0010200',
#  'C0231528',
#  'C0231617',
#  'C0001726',
#  'C0525041',
#  'C0232286',
#  'C0020453',
#  'C1619712',
#  'C0518214',
#  'C0009812',
#  'C0455270',
#  'C0234245',
#  'C0232602',
#  'C0241042',
#  'C1260880',
#  'C0032781',
#  'C0028081',
#  'C0015230',
#  'C0018834',
#  'C0242429',
#  'C0003862',
#  'C0019559',
#  'C0037090',
#  'C0425443',
#  'C0043144',
#  'C0221261',
#  'C1511887',
#  'C0030196',
#  'C0458257',
#  'C0239783',
#  'C0240007',
#  'C0235031',
#  'C0751378',
#  'C0018991',
#  'C0221232',
#  'C0023222',
#  'C0027796',
#  'C0239589',
#  'C0522051',
#  'C0018989',
#  'C0030794',
#  'C3714772',
#  'C5139160',
#  'C0393588',
#  'C0850149',
#  'C0019079',
#  'C0577573',
#  'C0016382',
#  'C0042571',
#  'C0221586',
#  'C0240211',
#  'C2347315',
#  'C0011991',
#  'C0239233',
#  'C0522251',
#  'C0266836',
#  'C0018681',
#  'C0040822',
#  'C0234376',
#  'C4551520',
#  'C0037763',
#  'C0237326',
#  'C0003564',
#  'C0003578',
#  'C0857494',
#  'C2219850',
#  'C0234966',
#  'C2985287',
#  'C0233212',
#  'C0425449',
#  'C0027066',
#  'C2013199',
#  'C0019825',
#  'C0241416',
#  'C0270697',
#  'C0232283',
#  'C0240608',
#  'C2004489',
#  'C1334804',
#  'C0424790',
#  'C0026837',
#  'C0085593',
#  'C0019214',
#  'C0241144',
#  'C0427008',
#  'C0162298',
#  'C0241898',
#  'C0036572',
#  'C0231592',
#  'C0234233',
#  'C0239739',
#  'C0085606',
#  'C0013428',
#  'C0152169',
#  'C0426576',
#  'C0426575',
#  'C0037089',
#  'C0271188',
#  'C0006625',
#  'C0235267',
#  'C1397014',
#  'C0085636',
#  'C0751900',
#  'C0022346',
#  'C0232608',
#  'C0741034',
#  'C0238741',
#  'C4552061',
#  'C0014724',
#  'C0151826',
#  'C0007859',
#  'C0476280',
#  'C0233762',
#  'C0476281',
#  'C0034880',
#  'C4025811',
#  'C0234253',
#  'C0221585',
#  'C0238656',
#  'C0240444',
#  'C0231618',
#  'C2936373',
#  'C0026961',
#  'C0221727',
#  'C3829514',
#  'C0349410',
#  'C0005904',
#  'C0574002',
#  'C4527152',
#  'C0231807',
#  'C0235242',
#  'C1517205',
#  'C0151908',
#  'C0015644',
#  'C3808668',
#  'C2129214',
#  'C0231852',
#  'C0600142',
#  'C0234254',
#  'C0158369',
#  'C0520963',
#  'C0010520',
#  'C0521800',
#  'C0599766',
#  'C0017672',
#  'C0221150',
#  'C0677600',
#  'C0085631',
#  'C0221512',
#  'C0221785',
#  'C0005874',
#  'C0427086',
#  'C0423636',
#  'C0151315',
#  'C0234378',
#  'C0476223',
#  'C2985217',
#  'C0152032',
#  'C0231749',
#  'C0240129',
#  'C0751188',
#  'C0426070',
#  'C0231710',
#  'C2242996',
#  'C0520962',
#  'C0854069',
#  'C0237089',
#  'C0426636',
#  'C0853945',
#  'C0241136',
#  'C0267028',
#  'C0497364',
#  'C0392171',
#  'C0033775',
#  'C0239653',
#  'C0423006',
#  'C0013456',
#  'C0578044',
#  'C0240940',
#  'C0085641',
#  'C0240805',
#  'C3494358',
#  'C0235108',
#  'C0038450',
#  'C0015468',
#  'C0240717',
#  'C0278146',
#  'C0853813',
#  'C2364111',
#  'C0687713',
#  'C0221776',
#  'C0518179',
#  'C0277873',
#  'C3838912',
#  'C0752303',
#  'C0752252',
#  'C0007939',
#  'C2169806',
#  'C0232943',
#  'C0344304',
#  'C0018926',
#  'C0221597',
#  'C0236078',
#  'C0948786',
#  'C1304408',
#  'C2732413',
#  'C1850830',
#  'C0575090',
#  'C0020450',
#  'C0235250',
#  'C0240928',
#  'C0234379',
#  'C0239842',
#  'C1321898',
#  'C0474368',
#  'C0009806',
#  'C0233766',
#  'C0233401',
#  'C4293708',
#  'C0302539',
#  'C0032617',
#  'C0085602',
#  'C0020175',
#  'C0848771',
#  'C0151786',
#  'C0151825',
#  'C0029089',
#  'C4048158',
#  'C0235169',
#  'C0740577',
#  'C0009024',
#  'C0746674',
#  'C1662979',
#  'C1409715',
#  'C0026821',
#  'C1446787',
#  'C0023218',
#  'C0000729',
#  'C0542476',
#  'C0333243',
#  'C0240841',
#  'C0235299',
#  'C0233221',
#  'C0232462',
#  'C0004134',
#  'C0235162',
#  'C0406833',
#  'C4054314',
#  'C0151827',
#  'C3887611',
#  'C0392156',
#  'C0848332',
#  'C0234913',
#  'C0751837',
#  'C0231529',
#  'C0235568',
#  'C0277794',
#  'C0239313',
#  'C0234238',
#  'C0522067',
#  'C0040416',
#  'C1709099',
#  'C0149758',
#  'C0677500',
#  'C0281856',
#  'C3640017',
#  'C0278141',
#  'C1333034',
#  'C3640010',
#  'C3494359',
#  'C3494361',
#  'C3494360',
#  'C0027769',
#  'C0751295',
#  'C0426359',
#  'C0574785',
#  'C0232498',
#  'C0853946',
#  'C0238637',
#  'C0042256',
#  'C0232726',
#  'C0750731',
#  'C0024902',
#  'C0401149',
#  'C0426908',
#  'C4293680',
#  'C0235707',
#  'C0264272',
#  'C0581362',
#  'C4293679',
#  'C0751564',
#  'C0751407',
#  'C0277976',
#  'C0277849',
#  'C0277978',
#  'C0233232',
#  'C0277977',
#  'C0232492',
#  'C1291077',
#  'C0238551',
#  'C0401148',
#  'C0278007',
#  'C3160897',
#  'C3257803',
#  'C0679309',
#  'C0232766',
#  'C0423701',
#  'C0520825',
#  'C0036396',
#  'C0497366',
#  'C0241374',
#  'C0542132',
#  'C4042866',
#  'C1280008',
#  'C0233200',
#  'C0241039',
#  'C0241040',
#  'C0030214',
#  'C0578454',
#  'C0040460',
#  'C0241462',
#  'C1282310',
#  'C0018520',
#  'C0560024',
#  'C0178782',
#  'C0037383',
#  'C0424810',
#  'C0239223',
#  'C0576836',
#  'C0497293',
#  'C0423625',
#  'C0314719',
#  'C0333274',
#  'C0578050',
#  'C0040485',
#  'C0152116',
#  'C2141086',
#  'C2201627',
#  'C1705500',
#  'C0332601',
#  'C0751401',
#  'C0751192',
#  'C0008039',
#  'C0152165',
#  'C0849791',
#  'C0239511',
#  'C0239886',
#  'C0700153',
#  'C0026838',
#  'C2242577',
#  'C0013421',
#  'C0423621',
#  'C0234133',
#  'C0221588',
#  'C0740903',
#  'C0586407',
#  'C0948715',
#  'C0239266',
#  'C0221201',
#  'C0241310',
#  'C0749874',
#  'C0747149',
#  'C0812426',
#  'C0240327',
#  'C0231785',
#  'C0232476',
#  'C1710621',
#  'C0567085',
#  'C0234244',
#  'C0234250',
#  'C4551516',
#  'C0159066',
#  'C0242453',
#  'C0233407',
#  'C0743323',
#  'C3266098',
#  'C0151442',
#  'C0740418',
#  'C0699896',
#  'C0221166',
#  'C0917801',
#  'C0597470',
#  'C0474585',
#  'C0239957',
#  'C0234179',
#  'C3839719',
#  'C0239888',
#  'C0231239',
#  'C0751077',
#  'C0849963',
#  'C0521516',
#  'C0239596',
#  'C0744633',
#  'C0235068',
#  'C0234461',
#  'C0747150',
#  'C0277821',
#  'C0221730',
#  'C0751535',
#  'C0149746',
#  'C0751536',
#  'C2364082',
#  'C0234542',
#  'C0221170',
#  'C0231765',
#  'C0026825',
#  'C0871189',
#  'C0028084',
#  'C0235218',
#  'C0025287',
#  'C0010201',
#  'C0239182',
#  'C2609319',
#  'C0037317',
#  'C4732758',
#  'C0497481',
#  'C0278147',
#  'C0239091',
#  'C0857057',
#  'C0425791',
#  'C0333422',
#  'C4531172',
#  'C3839361',
#  'C0240094',
#  'C0234255',
#  'C0235018',
#  'C0037771',
#  'C0240419',
#  'C0575064',
#  'C0409326',
#  'C0578051',
#  'C0877781',
#  'C0231613',
#  'C0750403',
#  'C0522357',
#  'C0233187',
#  'C2985289',
#  'C0282666',
#  'C0312414',
#  'C0497431',
#  'C0850758',
#  'C0404484',
#  'C0745411',
#  'C0341742',
#  'C0023533',
#  'C4477064',
#  'C0567083',
#  'C0151564',
#  'C0152149',
#  'C0262397',
#  'C0392674',
#  'C0741933',
#  'C2228804',
#  'C0235014',
#  'C0549209',
#  'C0241902',
#  'C0232502',
#  'C0241706',
#  'C0087169',
#  'C0234374',
#  'C0234369',
#  'C0857516',
#  'C0221151',
#  'C0232487',
#  'C1740793',
#  'C0221200',
#  'C0750323',
#  'C1112500',
#  'C0237322',
#  'C0564821',
#  'C2126412',
#  'C0740389',
#  'C0239272',
#  'C0231780',
#  'C0853619',
#  'C0233765',
#  'C0860603',
#  'C0877167',
#  'C0277848',
#  'C0426980',
#  'C0312422',
#  'C0013911',
#  'C0232598',
#  'C0522046',
#  'C3900051',
#  'C0423641',
#  'C1282799',
#  'C0232849',
#  'C0559687',
#  'C0233205',
#  'C0270790',
#  'C0562483',
#  'C0742857',
#  'C0231891',
#  'C0231890',
#  'C0241235',
#  'C0848337',
#  'C3640016',
#  'C0221100',
#  'C0393756',
#  'C0312416',
#  'C3888418',
#  'C0232597',
#  'C4477048',
#  'C2363731',
#  'C0020429',
#  'C0548823',
#  'C0422943',
#  'C0151767',
#  'C0235634',
#  'C0282005',
#  'C0857180',
#  'C0741451',
#  'C2032420',
#  'C0016512',
#  'C0025587',
#  'C0751534',
#  'C0231451',
#  'C0277845']

# %%
symptom_df = pd.DataFrame(symptom_cuis, columns=['cui'])
symptom_df = symptom_df.sort_values(by=['cui'])
symptom_df
# Out:
#           cui
# 13   C0000727
# 310  C0000729
# 0    C0000737
# 76   C0001726
# 34   C0002962
# ..        ...
# 443  C4551516
# 132  C4551520
# 180  C4552061
# 487  C4732758
# 115  C5139160
#
# [592 rows x 1 columns]

# %%
symptom_df

# %%
def get_cui_name(cui):
    return linker.kb.cui_to_entity[cui][1]
get_cui_name('C0000737')
# Out:
# 'Abdominal Pain'

# %%
symptom_df['symptom'] = symptom_df.cui.apply(get_cui_name)
symptom_df
# Out:
#           cui                 symptom
# 13   C0000727          Abdomen, Acute
# 310  C0000729        Abdominal Cramps
# 0    C0000737          Abdominal Pain
# 76   C0001726      Affective Symptoms
# 34   C0002962         Angina Pectoris
# ..        ...                     ...
# 443  C4551516                Hip pain
# 132  C4551520        Intention tremor
# 180  C4552061         Mandibular pain
# 487  C4732758   Gastrocnemius myalgia
# 115  C5139160  Paroxysmal rectal pain
#
# [592 rows x 2 columns]

# %%
symptom_df.to_csv('signs_or_symptoms.csv', index=False)

# %%
injury_or_poisoning_cuis = []
for line in tqdm(df.content.astype(str).tolist()):
    doc = nlp(line)
    # print(doc.ents)
    for entity in doc.ents:
        try:
            # print(entity._.kb_ents)
            for cui in entity._.kb_ents:
                # print(cui)
                cui_to_ent = linker.kb.cui_to_entity[cui[0]]
                # print(cui_to_ent)
                if 'T037' in cui_to_ent[3]:
                    # print('success')
                    if cui[0] not in injury_or_poisoning_cuis:
                        injury_or_poisoning_cuis.append(cui[0])    
        except:
            continue
injury_or_poisoning_df = pd.DataFrame(injury_or_poisoning_cuis, columns=['cui'])
injury_or_poisoning_df = injury_or_poisoning_df.sort_values(by=['cui'])
injury_or_poisoning_df['name'] = injury_or_poisoning_df.cui.apply(get_cui_name)
injury_or_poisoning_df.to_csv('injury_or_poisoning.csv', index=False)
# Out:
#   0%|          | 0/61969 [00:00<?, ?it/s]

# %%
disease_or_syndrome_cuis = []
for line in tqdm(df.content.astype(str).tolist()):
    doc = nlp(line)
    # print(doc.ents)
    for entity in doc.ents:
        try:
            # print(entity._.kb_ents)
            for cui in entity._.kb_ents:
                # print(cui)
                cui_to_ent = linker.kb.cui_to_entity[cui[0]]
                # print(cui_to_ent)
                if 'T047' in cui_to_ent[3]:
                    # print('success')
                    if cui[0] not in disease_or_syndrome_cuis:
                        disease_or_syndrome_cuis.append(cui[0])    
        except:
            continue
disease_or_syndrome_df = pd.DataFrame(disease_or_syndrome_cuis, columns=['cui'])
disease_or_syndrome_df = disease_or_syndrome_df.sort_values(by=['cui'])
disease_or_syndrome_df['name'] = disease_or_syndrome_df.cui.apply(get_cui_name)
disease_or_syndrome_df.to_csv('disease_or_syndrome.csv', index=False)
# Out:
#   0%|          | 0/61969 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-104-7de702879d7f> in <module>
#       1 disease_or_syndrome_cuis = []
#       2 for line in tqdm(df.content.astype(str).tolist()):
# ----> 3     doc = nlp(line)
#       4     # print(doc.ents)
#       5     for entity in doc.ents:
#
# ~/opt/anaconda3/envs/em-spacy/lib/python3.8/site-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#     993                 error_handler = proc.get_error_handler()
#     994             try:
# --> 995                 doc = proc(doc, **component_cfg.get(name, {}))
#     996             except KeyError as e:
#     997                 # This typically happens if a component is not initialized
#
# ~/opt/anaconda3/envs/em-spacy/lib/python3.8/site-packages/spacy/pipeline/trainable_pipe.pyx in spacy.pipeline.trainable_pipe.TrainablePipe.__call__()
#
# ~/opt/anaconda3/envs/em-spacy/lib/python3.8/site-packages/spacy/pipeline/tok2vec.py in predict(self, docs)
#     119         DOCS: https://spacy.io/api/tok2vec#predict
#     120         """
# --> 121         tokvecs = self.model.predict(docs)
#     122         batch_id = Tok2VecListener.get_batch_id(docs)
#     123         for listener in self.listeners:
#
# ~/opt/anaconda3/envs/em-spacy/lib/python3.8/site-packages/thinc/model.py in predict(self, X)
#     310         only the output, instead of the `(output, callback)` tuple.
#     311         """
# --> 312         return self._func(self, X, is_train=False)[0]
#     313
#     314     def finish_update(self, optimizer: Optimizer) -> None:
#
# ~/opt/anaconda3/envs/em-spacy/lib/python3.8/site-packages/thinc/layers/chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# ~/opt/anaconda3/envs/em-spacy/lib/python3.8/site-packages/thinc/model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~/opt/anaconda3/envs/em-spacy/lib/python3.8/site-packages/thinc/layers/with_array.py in forward(model, Xseq, is_train)
#      38         return model.layers[0](Xseq, is_train)
#      39     else:
# ---> 40         return _list_forward(cast(Model[List2d, List2d], model), Xseq, is_train)
#      41
#      42
#
# ~/opt/anaconda3/envs/em-spacy/lib/python3.8/site-packages/thinc/layers/with_array.py in _list_forward(model, Xs, is_train)
#      74     lengths = layer.ops.asarray1i([len(seq) for seq in Xs])
#      75     Xf = layer.ops.flatten(Xs, pad=pad)  # type: ignore
# ---> 76     Yf, get_dXf = layer(Xf, is_train)
#      77
#      78     def backprop(dYs: List2d) -> List2d:
#
# ~/opt/anaconda3/envs/em-spacy/lib/python3.8/site-packages/thinc/model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~/opt/anaconda3/envs/em-spacy/lib/python3.8/site-packages/thinc/layers/chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# ~/opt/anaconda3/envs/em-spacy/lib/python3.8/site-packages/thinc/model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~/opt/anaconda3/envs/em-spacy/lib/python3.8/site-packages/thinc/layers/residual.py in forward(model, X, is_train)
#      38             return d_output + dX
#      39
# ---> 40     Y, backprop_layer = model.layers[0](X, is_train)
#      41     if isinstance(X, list):
#      42         return [X[i] + Y[i] for i in range(len(X))], backprop
#
# ~/opt/anaconda3/envs/em-spacy/lib/python3.8/site-packages/thinc/model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~/opt/anaconda3/envs/em-spacy/lib/python3.8/site-packages/thinc/layers/chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# ~/opt/anaconda3/envs/em-spacy/lib/python3.8/site-packages/thinc/model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~/opt/anaconda3/envs/em-spacy/lib/python3.8/site-packages/thinc/layers/chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# ~/opt/anaconda3/envs/em-spacy/lib/python3.8/site-packages/thinc/model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~/opt/anaconda3/envs/em-spacy/lib/python3.8/site-packages/thinc/layers/chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# ~/opt/anaconda3/envs/em-spacy/lib/python3.8/site-packages/thinc/model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~/opt/anaconda3/envs/em-spacy/lib/python3.8/site-packages/thinc/layers/layernorm.py in forward(model, X, is_train)
#      23
#      24 def forward(model: Model[InT, InT], X: InT, is_train: bool) -> Tuple[InT, Callable]:
# ---> 25     N, mu, var = _get_moments(model.ops, X)
#      26     Xhat = (X - mu) * var ** (-1.0 / 2.0)
#      27     Y, backprop_rescale = _begin_update_scale_shift(model, Xhat)
#
# ~/opt/anaconda3/envs/em-spacy/lib/python3.8/site-packages/thinc/layers/layernorm.py in _get_moments(ops, X)
#      74 def _get_moments(ops: Ops, X: Floats2d) -> Tuple[Floats2d, Floats2d, Floats2d]:
#      75     # TODO: Do mean methods
# ---> 76     mu: Floats2d = X.mean(axis=1, keepdims=True)
#      77     var: Floats2d = X.var(axis=1, keepdims=True) + 1e-08
#      78     return cast(Floats2d, ops.asarray_f([X.shape[1]])), mu, var
#
# ~/opt/anaconda3/envs/em-spacy/lib/python3.8/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims, where)
#     176             is_float16_result = True
#     177
# --> 178     ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
#     179     if isinstance(ret, mu.ndarray):
#     180         ret = um.true_divide(
#
# KeyboardInterrupt:

# %%
finding_cuis = []
for line in tqdm(df.content.astype(str).tolist()):
    doc = nlp(line)
    # print(doc.ents)
    for entity in doc.ents:
        try:
            # print(entity._.kb_ents)
            for cui in entity._.kb_ents:
                # print(cui)
                cui_to_ent = linker.kb.cui_to_entity[cui[0]]
                # print(cui_to_ent)
                if 'T033' in cui_to_ent[3]:
                    # print('success')
                    if cui[0] not in finding_cuis:
                        finding_cuis.append(cui[0])    
        except:
            continue
finding_df = pd.DataFrame(finding_cuis, columns=['cui'])
finding_df = finding_df.sort_values(by=['cui'])
finding_df['name'] = finding_df.cui.apply(get_cui_name)
finding_df.to_csv('finding_df.csv', index=False)

# %%
sem_types_df = pd.read_csv('semtypes.txt', sep='|', names=['abbr','TUI','name']).set_index('TUI')
sem_types_df
# Out:
#       abbr                                 name
# TUI
# T116  aapp      Amino Acid, Peptide, or Protein
# T020  acab                 Acquired Abnormality
# T052  acty                             Activity
# T100  aggp                            Age Group
# T087  amas                  Amino Acid Sequence
# ...    ...                                  ...
# T079  tmco                     Temporal Concept
# T061  topp  Therapeutic or Preventive Procedure
# T005  virs                                Virus
# T127  vita                              Vitamin
# T010  vtbt                           Vertebrate
#
# [127 rows x 2 columns]

# %%
sem_types_df.loc['T190']['name']
# Out:
# 'Anatomical Abnormality'

# %%
sem_type_targets = ['T190', 'T017', 'T195', 'T123', 'T007', 'T031', 'T022', 'T053', 'T038', 'T029', 'T091', 'T122', 'T023', 'T030', 'T019', 'T201', 'T200', 'T060', 'T203', 'T047', 'T033', 'T169', 'T093', 'T058', 'T131', 'T125', 'T078', 'T129', 'T037', 'T170', 'T130', 'T059', 'T034', 'T074', 'T041', 'T048', 'T191', 'T090', 'T042', 'T046', 'T039', 'T121', 'T101', 'T098', 'T167', 'T054', 'T184', 'T079', 'T061', 'T005', 'T127']
for sem_type in tqdm(sem_type_targets):
    cuis = []
    for line in tqdm(df.content.astype(str).tolist()):
        doc = nlp(line)
        # print(doc.ents)
        for entity in doc.ents:
            try:
                # print(entity._.kb_ents)
                for cui in entity._.kb_ents:
                    # print(cui)
                    cui_to_ent = linker.kb.cui_to_entity[cui[0]]
                    # print(cui_to_ent)
                    if sem_type in cui_to_ent[3]:
                        # print('success')
                        if cui[0] not in cuis:
                            cuis.append(cui[0])    
            except:
                continue
    cuis_df = pd.DataFrame(cuis, columns=['cui'])
    cuis_df = cuis_df.sort_values(by=['cui'])
    cuis_df['name'] = cuis_df.cui.apply(get_cui_name)
    cuis_df.to_csv('cuis/'+sem_type+' - '+sem_types_df.loc[sem_type]['name']+'.csv', index=False)
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]
#   0%|          | 0/61969 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-121-5c2b7d569f3b> in <module>
#       3     cuis = []
#       4     for line in tqdm(df.content.astype(str).tolist()):
# ----> 5         doc = nlp(line)
#       6         # print(doc.ents)
#       7         for entity in doc.ents:
#
# ~/opt/anaconda3/envs/em-spacy/lib/python3.8/site-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#     993                 error_handler = proc.get_error_handler()
#     994             try:
# --> 995                 doc = proc(doc, **component_cfg.get(name, {}))
#     996             except KeyError as e:
#     997                 # This typically happens if a component is not initialized
#
# KeyboardInterrupt:

# %%
cuis_df = pd.DataFrame(cuis, columns=['cui'])
cuis_df = cuis_df.sort_values(by=['cui'])
cuis_df['name'] = cuis_df.cui.apply(get_cui_name)
cuis_df.to_csv('cuis/'+sem_type+' - '+sem_types_df.loc[sem_type]['name']+'.csv', index=False)

# %%
sem_type_targets = ['T190', 'T017', 'T195', 'T123', 'T007', 'T031', 'T022', 'T053', 'T038', 'T029', 'T091', 'T122', 'T023', 'T030', 'T019', 'T201', 'T200', 'T060', 'T203', 'T047', 'T033', 'T169', 'T093', 'T058', 'T131', 'T125', 'T078', 'T129', 'T037', 'T170', 'T130', 'T059', 'T034', 'T074', 'T041', 'T048', 'T191', 'T090', 'T042', 'T046', 'T039', 'T121', 'T101', 'T098', 'T167', 'T054', 'T184', 'T079', 'T061', 'T005', 'T127']
for sem_type in tqdm(sem_type_targets):
    cuis = []
    for line in tqdm(df.content.astype(str).tolist()):
        doc = nlp(line)
        # print(doc.ents)
        for entity in doc.ents:
            try:
                # print(entity._.kb_ents)
                for cui in entity._.kb_ents:
                    # print(cui)
                    cui_to_ent = linker.kb.cui_to_entity[cui[0]]
                    # print(cui_to_ent)
                    if cui_to_ent[3][0] in sem_type_targets:
                        # print('success')
                        cuis.append(cui[0])    
            except:
                continue
    cuis_df = pd.DataFrame(cuis, columns=['cui'])
    cuis_df = cuis_df.sort_values(by=['cui'])
    cuis_df['name'] = cuis_df.cui.apply(get_cui_name)
    cuis_df.to_csv('cuis/'+sem_type+' - '+sem_types_df.loc[sem_type]['name']+'.csv', index=False)
